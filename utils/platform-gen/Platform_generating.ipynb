# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from generateFatTree import FatTree

# %% [markdown]
# # Generación de la topologia
# ![image.png](attachment:8a32716b-c1d7-48c7-9ece-16fd56c37f07.png)
#
# Primer paso es generar el Fat Tree a utilizar en la plataforma. La clase ´FatTree´ recibe los siguientes parametros:
# - levels: Int
# - Down links: list[int]
# - Up links: list[int]
# - Link Count: list[int]
# - Debug: Bool

# %%
arqui1 = FatTree(2,[4,4],[1,2],[1,2], True)
arqui1.generate()
# Out:
# [+] Creating 16 nodes
# [+] Routers by level [4, 2]
# [+] Creating router r10
# [+] Creating router r11
# [+] Creating router r12
# [+] Creating router r13
# [+] Creating router r20
# [+] Creating router r21
# ('r10-c0', {'src': 'r10', 'dst': 'c0', 'up': 1, 'dn': 1})
# ('r10-c1', {'src': 'r10', 'dst': 'c1', 'up': 1, 'dn': 1})
# ('r10-c2', {'src': 'r10', 'dst': 'c2', 'up': 1, 'dn': 1})
# ('r10-c3', {'src': 'r10', 'dst': 'c3', 'up': 1, 'dn': 1})
# ('r11-c4', {'src': 'r11', 'dst': 'c4', 'up': 1, 'dn': 1})
# ('r11-c5', {'src': 'r11', 'dst': 'c5', 'up': 1, 'dn': 1})
# ('r11-c6', {'src': 'r11', 'dst': 'c6', 'up': 1, 'dn': 1})
# ('r11-c7', {'src': 'r11', 'dst': 'c7', 'up': 1, 'dn': 1})
# ('r12-c8', {'src': 'r12', 'dst': 'c8', 'up': 1, 'dn': 1})
# ('r12-c9', {'src': 'r12', 'dst': 'c9', 'up': 1, 'dn': 1})
# ('r12-c10', {'src': 'r12', 'dst': 'c10', 'up': 1, 'dn': 1})
# ('r12-c11', {'src': 'r12', 'dst': 'c11', 'up': 1, 'dn': 1})
# ('r13-c12', {'src': 'r13', 'dst': 'c12', 'up': 1, 'dn': 1})
# ('r13-c13', {'src': 'r13', 'dst': 'c13', 'up': 1, 'dn': 1})
# ('r13-c14', {'src': 'r13', 'dst': 'c14', 'up': 1, 'dn': 1})
# ('r13-c15', {'src': 'r13', 'dst': 'c15', 'up': 1, 'dn': 1})
# ('r20-r10', {'src': 'r20', 'dst': 'r10', 'up': 2, 'dn': 2})
# ('r21-r10', {'src': 'r21', 'dst': 'r10', 'up': 2, 'dn': 2})
# ('r20-r11', {'src': 'r20', 'dst': 'r11', 'up': 2, 'dn': 2})
# ('r21-r11', {'src': 'r21', 'dst': 'r11', 'up': 2, 'dn': 2})
# ('r20-r12', {'src': 'r20', 'dst': 'r12', 'up': 2, 'dn': 2})
# ('r21-r12', {'src': 'r21', 'dst': 'r12', 'up': 2, 'dn': 2})
# ('r20-r13', {'src': 'r20', 'dst': 'r13', 'up': 2, 'dn': 2})
# ('r21-r13', {'src': 'r21', 'dst': 'r13', 'up': 2, 'dn': 2})

# %%
print(arqui1.nodes_by_level)
arqui1.draw()
# Out:
# [16, 4, 2]

# %%
arqui2 = FatTree(3,[4,2,2],[1,2,2],[1,2,1],False)
arqui2.generate()
print(arqui2.nodes_by_level)
arqui2.draw()
# Out:
# [16, 4, 4, 4]

# %% [markdown]
# # Selecting the hw specs
# Despues de generar el fat tree,
# 1. node_types.json
# 2.

# %% [markdown]
# ## DFVS
#
# attributes
# - speed: Computational power (per core, in flop/s). **If you use DVFS, provide a comma-separated list of values for each pstate**
# - pstate
#
# properties
# - wattage_per_state
# - wattage_off
# - sleep_pstates

# %%
# %%writefile node_types.json
# {
#     "node_A": {
#         "_coment": [
#             "pstate values:",
#             "* 0-2: real pstates",
#             "0: p1 100 MFlops/s, [idle: 95W -> full burning: 200W]",
#             "1: p2  50 MFlops/s, [idle: 93W -> full burning: 170W]",
#             "2: p3  20 MFlops/s, [idel: 90W -> full burning: 150W]"
#         ],
#         "attributes": { "speed": "100.0Mf,50.0Mf,20.0Mf", "pstate": "0" },
#         "properties": [
#             { "id": "wattage_per_state", "value": "95.0:200.0,93.0:170.0,90.0:150.0" },
#             { "id": "wattage_off", "value": "2.0" }
#         ]
#     },
#     "node_B": {
#         "attributes": { "speed": "10.0Gf, 0.05f", "pstate": "0" },
#         "properties": [
#             { "id": "wattage_per_state", "value": "10.0:100.0:7.0, 9.75:5:7.25" },
#             { "id": "wattage_off", "value": "2.0" }
#         ]
#     },
#     "node_C": {
#         "attributes": { "speed": "20.4Gf, 18.36Gf, 16.32Gf, 14.28Gf, 12.24Gf, 0.0Gf, 0.0Gf, 0.0Gf", "pstate": "0" },
#         "properties": [
#             { "id": "sleep_pstates", "value": "5:6:7"},
#             { "id": "wattage_per_state", "value": "5.0:14.375, 5.0:12.9375, 5.0:11.5, 5.0:10.0625, 5.0:8.625, 2.0:2.0, 7.0:7.0, 6.0:6.0" },
#             { "id": "wattage_off", "value": "2.0" }
#         ]
#     }
# }
# Out:
# Overwriting node_types.json

# %%
# %%writefile network_types.json
# {
#
# }
# Out:
# Overwriting network_types.json

# %%
# %%writefile test02.json
# {
#     "nodes": [
#         { "type": "node_A", "number": "6" },
#         { "type": "node_B", "number": "10" }
#     ],
#     "cluster_network": "Network A",
#     "dc_network": "Network A"
# }
# Out:
# Overwriting test02.json

# %% [markdown]
# # Generating the plaform file

# %%
from generateFatTree import FileInterface

# %%
PLATFORM_IN  = "test02.json"
PLATFORM_OUT = "generated.xml"

iface = FileInterface(PLATFORM_IN, PLATFORM_OUT)
iface.write(arqui1)

# %%
# !cat generated.xml
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <!DOCTYPE platform
#   SYSTEM 'https://simgrid.org/simgrid.dtd'>
# <platform version="4.1">
#     <zone id="main" routing="Full">
#         <zone id="cluster_compute" routing="Full">
#             <host speed="100.0Mf,50.0Mf,20.0Mf" pstate="0" id="c0">
#                 <prop id="wattage_per_state" value="95.0:200.0,93.0:170.0,90.0:150.0"/>
#                 <prop id="wattage_off" value="2.0"/>
#                 <prop id="type" value="node_A"/>
#             </host>
#             <host speed="100.0Mf,50.0Mf,20.0Mf" pstate="0" id="c1">
#                 <prop id="wattage_per_state" value="95.0:200.0,93.0:170.0,90.0:150.0"/>
#                 <prop id="wattage_off" value="2.0"/>
#                 <prop id="type" value="node_A"/>
#             </host>
#             <host speed="100.0Mf,50.0Mf,20.0Mf" pstate="0" id="c2">
#                 <prop id="wattage_per_state" value="95.0:200.0,93.0:170.0,90.0:150.0"/>
#                 <prop id="wattage_off" value="2.0"/>
#                 <prop id="type" value="node_A"/>
#             </host>
#             <host speed="100.0Mf,50.0Mf,20.0Mf" pstate="0" id="c3">
#                 <prop id="wattage_per_state" value="95.0:200.0,93.0:170.0,90.0:150.0"/>
#                 <prop id="wattage_off" value="2.0"/>
#                 <prop id="type" value="node_A"/>
#             </host>
#             <host speed="100.0Mf,50.0Mf,20.0Mf" pstate="0" id="c4">
#                 <prop id="wattage_per_state" value="95.0:200.0,93.0:170.0,90.0:150.0"/>
#                 <prop id="wattage_off" value="2.0"/>
#                 <prop id="type" value="node_A"/>
#             </host>
#             <host speed="100.0Mf,50.0Mf,20.0Mf" pstate="0" id="c5">
#                 <prop id="wattage_per_state" value="95.0:200.0,93.0:170.0,90.0:150.0"/>
#                 <prop id="wattage_off" value="2.0"/>
#                 <prop id="type" value="node_A"/>
#             </host>
#             <host speed="10.0Gf, 0.05f" pstate="0" id="c6">
#                 <prop id="wattage_per_state" value="10.0:100.0:7.0, 9.75:5:7.25"/>
#                 <prop id="wattage_off" value="2.0"/>
#                 <prop id="type" value="node_B"/>
#             </host>
#             <host speed="10.0Gf, 0.05f" pstate="0" id="c7">
#                 <prop id="wattage_per_state" value="10.0:100.0:7.0, 9.75:5:7.25"/>
#                 <prop id="wattage_off" value="2.0"/>
#                 <prop id="type" value="node_B"/>
#             </host>
#             <host speed="10.0Gf, 0.05f" pstate="0" id="c8">
#                 <prop id="wattage_per_state" value="10.0:100.0:7.0, 9.75:5:7.25"/>
#                 <prop id="wattage_off" value="2.0"/>
#                 <prop id="type" value="node_B"/>
#             </host>
#             <host speed="10.0Gf, 0.05f" pstate="0" id="c9">
#                 <prop id="wattage_per_state" value="10.0:100.0:7.0, 9.75:5:7.25"/>
#                 <prop id="wattage_off" value="2.0"/>
#                 <prop id="type" value="node_B"/>
#             </host>
#             <host speed="10.0Gf, 0.05f" pstate="0" id="c10">
#                 <prop id="wattage_per_state" value="10.0:100.0:7.0, 9.75:5:7.25"/>
#                 <prop id="wattage_off" value="2.0"/>
#                 <prop id="type" value="node_B"/>
#             </host>
#             <host speed="10.0Gf, 0.05f" pstate="0" id="c11">
#                 <prop id="wattage_per_state" value="10.0:100.0:7.0, 9.75:5:7.25"/>
#                 <prop id="wattage_off" value="2.0"/>
#                 <prop id="type" value="node_B"/>
#             </host>
#             <host speed="10.0Gf, 0.05f" pstate="0" id="c12">
#                 <prop id="wattage_per_state" value="10.0:100.0:7.0, 9.75:5:7.25"/>
#                 <prop id="wattage_off" value="2.0"/>
#                 <prop id="type" value="node_B"/>
#             </host>
#             <host speed="10.0Gf, 0.05f" pstate="0" id="c13">
#                 <prop id="wattage_per_state" value="10.0:100.0:7.0, 9.75:5:7.25"/>
#                 <prop id="wattage_off" value="2.0"/>
#                 <prop id="type" value="node_B"/>
#             </host>
#             <host speed="10.0Gf, 0.05f" pstate="0" id="c14">
#                 <prop id="wattage_per_state" value="10.0:100.0:7.0, 9.75:5:7.25"/>
#                 <prop id="wattage_off" value="2.0"/>
#                 <prop id="type" value="node_B"/>
#             </host>
#             <host speed="10.0Gf, 0.05f" pstate="0" id="c15">
#                 <prop id="wattage_per_state" value="10.0:100.0:7.0, 9.75:5:7.25"/>
#                 <prop id="wattage_off" value="2.0"/>
#                 <prop id="type" value="node_B"/>
#             </host>
#             <router id="r10"/>
#             <router id="r11"/>
#             <router id="r12"/>
#             <router id="r13"/>
#             <router id="r20"/>
#             <router id="r21"/>
#             <router id="router_master"/>
#             <link id="r10-c0-uplink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r10-c0-downlink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r10-c1-uplink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r10-c1-downlink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r10-c2-uplink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r10-c2-downlink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r10-c3-uplink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r10-c3-downlink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r11-c4-uplink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r11-c4-downlink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r11-c5-uplink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r11-c5-downlink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r11-c6-uplink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r11-c6-downlink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r11-c7-uplink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r11-c7-downlink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r12-c8-uplink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r12-c8-downlink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r12-c9-uplink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r12-c9-downlink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r12-c10-uplink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r12-c10-downlink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r12-c11-uplink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r12-c11-downlink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r13-c12-uplink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r13-c12-downlink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r13-c13-uplink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r13-c13-downlink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r13-c14-uplink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r13-c14-downlink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r13-c15-uplink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r13-c15-downlink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r20-r10-uplink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r20-r10-uplink1" bandwidth="125MBps" latency="100us"/>
#             <link id="r20-r10-downlink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r20-r10-downlink1" bandwidth="125MBps" latency="100us"/>
#             <link id="r21-r10-uplink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r21-r10-uplink1" bandwidth="125MBps" latency="100us"/>
#             <link id="r21-r10-downlink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r21-r10-downlink1" bandwidth="125MBps" latency="100us"/>
#             <link id="r20-r11-uplink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r20-r11-uplink1" bandwidth="125MBps" latency="100us"/>
#             <link id="r20-r11-downlink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r20-r11-downlink1" bandwidth="125MBps" latency="100us"/>
#             <link id="r21-r11-uplink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r21-r11-uplink1" bandwidth="125MBps" latency="100us"/>
#             <link id="r21-r11-downlink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r21-r11-downlink1" bandwidth="125MBps" latency="100us"/>
#             <link id="r20-r12-uplink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r20-r12-uplink1" bandwidth="125MBps" latency="100us"/>
#             <link id="r20-r12-downlink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r20-r12-downlink1" bandwidth="125MBps" latency="100us"/>
#             <link id="r21-r12-uplink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r21-r12-uplink1" bandwidth="125MBps" latency="100us"/>
#             <link id="r21-r12-downlink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r21-r12-downlink1" bandwidth="125MBps" latency="100us"/>
#             <link id="r20-r13-uplink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r20-r13-uplink1" bandwidth="125MBps" latency="100us"/>
#             <link id="r20-r13-downlink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r20-r13-downlink1" bandwidth="125MBps" latency="100us"/>
#             <link id="r21-r13-uplink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r21-r13-uplink1" bandwidth="125MBps" latency="100us"/>
#             <link id="r21-r13-downlink0" bandwidth="125MBps" latency="100us"/>
#             <link id="r21-r13-downlink1" bandwidth="125MBps" latency="100us"/>
#             <link id="router_master-r20" bandwidth="125MBps" latency="100us"/>
#             <link id="router_master-r21" bandwidth="125MBps" latency="100us"/>
#             <route src="r10" dst="c0">
#                 <link_ctn id="r10-c0-uplink0"/>
#                 <link_ctn id="r10-c0-downlink0"/>
#             </route>
#             <route src="r10" dst="c1">
#                 <link_ctn id="r10-c1-uplink0"/>
#                 <link_ctn id="r10-c1-downlink0"/>
#             </route>
#             <route src="r10" dst="c2">
#                 <link_ctn id="r10-c2-uplink0"/>
#                 <link_ctn id="r10-c2-downlink0"/>
#             </route>
#             <route src="r10" dst="c3">
#                 <link_ctn id="r10-c3-uplink0"/>
#                 <link_ctn id="r10-c3-downlink0"/>
#             </route>
#             <route src="r11" dst="c4">
#                 <link_ctn id="r11-c4-uplink0"/>
#                 <link_ctn id="r11-c4-downlink0"/>
#             </route>
#             <route src="r11" dst="c5">
#                 <link_ctn id="r11-c5-uplink0"/>
#                 <link_ctn id="r11-c5-downlink0"/>
#             </route>
#             <route src="r11" dst="c6">
#                 <link_ctn id="r11-c6-uplink0"/>
#                 <link_ctn id="r11-c6-downlink0"/>
#             </route>
#             <route src="r11" dst="c7">
#                 <link_ctn id="r11-c7-uplink0"/>
#                 <link_ctn id="r11-c7-downlink0"/>
#             </route>
#             <route src="r12" dst="c8">
#                 <link_ctn id="r12-c8-uplink0"/>
#                 <link_ctn id="r12-c8-downlink0"/>
#             </route>
#             <route src="r12" dst="c9">
#                 <link_ctn id="r12-c9-uplink0"/>
#                 <link_ctn id="r12-c9-downlink0"/>
#             </route>
#             <route src="r12" dst="c10">
#                 <link_ctn id="r12-c10-uplink0"/>
#                 <link_ctn id="r12-c10-downlink0"/>
#             </route>
#             <route src="r12" dst="c11">
#                 <link_ctn id="r12-c11-uplink0"/>
#                 <link_ctn id="r12-c11-downlink0"/>
#             </route>
#             <route src="r13" dst="c12">
#                 <link_ctn id="r13-c12-uplink0"/>
#                 <link_ctn id="r13-c12-downlink0"/>
#             </route>
#             <route src="r13" dst="c13">
#                 <link_ctn id="r13-c13-uplink0"/>
#                 <link_ctn id="r13-c13-downlink0"/>
#             </route>
#             <route src="r13" dst="c14">
#                 <link_ctn id="r13-c14-uplink0"/>
#                 <link_ctn id="r13-c14-downlink0"/>
#             </route>
#             <route src="r13" dst="c15">
#                 <link_ctn id="r13-c15-uplink0"/>
#                 <link_ctn id="r13-c15-downlink0"/>
#             </route>
#             <route src="r20" dst="r10">
#                 <link_ctn id="r20-r10-uplink0"/>
#                 <link_ctn id="r20-r10-uplink1"/>
#                 <link_ctn id="r20-r10-downlink0"/>
#                 <link_ctn id="r20-r10-downlink1"/>
#             </route>
#             <route src="r21" dst="r10">
#                 <link_ctn id="r21-r10-uplink0"/>
#                 <link_ctn id="r21-r10-uplink1"/>
#                 <link_ctn id="r21-r10-downlink0"/>
#                 <link_ctn id="r21-r10-downlink1"/>
#             </route>
#             <route src="r20" dst="r11">
#                 <link_ctn id="r20-r11-uplink0"/>
#                 <link_ctn id="r20-r11-uplink1"/>
#                 <link_ctn id="r20-r11-downlink0"/>
#                 <link_ctn id="r20-r11-downlink1"/>
#             </route>
#             <route src="r21" dst="r11">
#                 <link_ctn id="r21-r11-uplink0"/>
#                 <link_ctn id="r21-r11-uplink1"/>
#                 <link_ctn id="r21-r11-downlink0"/>
#                 <link_ctn id="r21-r11-downlink1"/>
#             </route>
#             <route src="r20" dst="r12">
#                 <link_ctn id="r20-r12-uplink0"/>
#                 <link_ctn id="r20-r12-uplink1"/>
#                 <link_ctn id="r20-r12-downlink0"/>
#                 <link_ctn id="r20-r12-downlink1"/>
#             </route>
#             <route src="r21" dst="r12">
#                 <link_ctn id="r21-r12-uplink0"/>
#                 <link_ctn id="r21-r12-uplink1"/>
#                 <link_ctn id="r21-r12-downlink0"/>
#                 <link_ctn id="r21-r12-downlink1"/>
#             </route>
#             <route src="r20" dst="r13">
#                 <link_ctn id="r20-r13-uplink0"/>
#                 <link_ctn id="r20-r13-uplink1"/>
#                 <link_ctn id="r20-r13-downlink0"/>
#                 <link_ctn id="r20-r13-downlink1"/>
#             </route>
#             <route src="r21" dst="r13">
#                 <link_ctn id="r21-r13-uplink0"/>
#                 <link_ctn id="r21-r13-uplink1"/>
#                 <link_ctn id="r21-r13-downlink0"/>
#                 <link_ctn id="r21-r13-downlink1"/>
#             </route>
#             <route src="router_master" dst="r20">
#                 <link_ctn id="router_master-r20"/>
#             </route>
#             <route src="router_master" dst="r21">
#                 <link_ctn id="router_master-r21"/>
#             </route>
#         </zone>
#         <cluster id="cluster_master" prefix="master_host" suffix="" radical="0-0" speed="100.0Mf" bw="125MBps" lat="50us" bb_bw="2.25GBps" bb_lat="500us">
#             <prop id="role" value="master"/>
#         </cluster>
#         <link id="backbone" bandwidth="1.25GBps" latency="500us"/>
#         <zoneRoute src="cluster_compute" dst="cluster_master" gw_src="router_master" gw_dst="master_hostcluster_master_router">
#             <link_ctn id="backbone"/>
#         </zoneRoute>
#     </zone>
# </platform>

# %%
# !cp generated.xml ../../platforms/fat_tree.xml
